# %%
import pandas as pd

df = pd.read_csv("./data/rnc_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   itemId               3000 non-null   int64
#  1   sourceMcId           3000 non-null   int64
#  2   sourceMcTitle        3000 non-null   object
#  3   description          3000 non-null   object
#  4   targetDetectedMcIds  3000 non-null   object
#  5   targetSplitMcIds     3000 non-null   object
#  6   shouldSplit          3000 non-null   bool
#  7   caseType             3000 non-null   object
#  8   split                3000 non-null   object
# dtypes: bool(1), int64(2), object(6)
# memory usage: 190.6+ KB

# %%
ids = df["sourceMcId"].unique()

mc = {}

for id in ids:
    title = df[df["sourceMcId"] == id]["sourceMcTitle"].unique()[0]
    mc[id] = title

mc
# Out:
# [108 101 109 102 106 107 111 110 105 104 103]
# {np.int64(108): 'Штукатурные работы',
#  np.int64(101): 'Ремонт квартир и домов под ключ',
#  np.int64(109): 'Напольные покрытия',
#  np.int64(102): 'Сантехника',
#  np.int64(106): 'Поклейка обоев',
#  np.int64(107): 'Малярные работы',
#  np.int64(111): 'Демонтажные работы',
#  np.int64(110): 'Гипсокартон',
#  np.int64(105): 'Укладка плитки',
#  np.int64(104): 'Натяжные потолки',
#  np.int64(103): 'Электрика'}

# %%
df["sourceMcId"].agg()
# Out:
#   Cell In[5], line 1
#     df[]
#        ^
# SyntaxError: invalid syntax
